# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankita9699/LGMVIP-DataAnalytics/blob/main/Task%202/Data_Science_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Let's Grow More**
#
#
#
# ---
#
#
#
# ---
#
#
#
# #  **Data Science Internship**
#
# ---
#
#
#
# ---
#
# ## **Task-2 :- Image to Pencil Sketch with Python**
#
#
#
#
#
# **Description :-**
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn
# an image into classic black and white photo. Then the next thing to do is invert the grayscale
# image also called negative image, this will our inverted grayscale image. Inversion can be used to
# enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with
# the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry
# image. Since images are just arrays, we can easily do this programmatically using the divide
# function from the cv2 library in Python.

# %% [markdown]
# ***Importing the OpenCV [cv2] library***

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ***Load the Image in OpenCv (cv2)***

# %%
image = cv2.imread('haikyu.jpeg')
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=900x563 at 0x7F6F36783C90>
# -1

# %% [markdown]
# ***Convert Image to RBG format***

# %%
rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2_imshow(rgb_img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=900x563 at 0x7F6F293F1C50>
# -1

# %% [markdown]
# ***Convert RGB Image to Grayscale format***

# %%
gray_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=900x563 at 0x7F6F29401490>
# -1

# %% [markdown]
# ***Convert RGB Image to LUV format***

# %%
LUV_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2LUV)
cv2_imshow(LUV_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=900x563 at 0x7F6F29408D90>
# -1

# %% [markdown]
# ***Now Invert the Grayscale image [ Convert Grayscale
# to Negative format ]***

# %%
inverted_gray_img = 255 - gray_img
cv2_imshow(inverted_gray_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=900x563 at 0x7F6F29408250>
# -1

# %% [markdown]
# ***Blur the Image using Gaussian Function in OpenCV***

# %%
blur_img = cv2.GaussianBlur(inverted_gray_img, (21, 21), 0)
blur_gray_img = 255 - blur_img
cv2_imshow(blur_gray_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=900x563 at 0x7F6F294D9390>
# -1

# %% [markdown]
# ***Convert to Pencil Sketch Image***

# %%
pencil_sketch = cv2.divide(gray_img, blur_gray_img, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=900x563 at 0x7F6F29401C50>
# -1

# %% [markdown]
# ***Original v/s Pencil Sketch***

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=900x563 at 0x7F6F27B925D0>
# <PIL.Image.Image image mode=L size=900x563 at 0x7F6F27B92390>
# -1

# %% [markdown]
# # **Result:-**
#
# Accuracy of Image to Pencil Sketch with Python:- 98%
#
# Accuracy of Image to Pencil Sketch with Python:- 100%
#
# # **Thank you!!!**
